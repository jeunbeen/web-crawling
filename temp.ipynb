# %%
from urllib.request import Request, urlopen
from urllib.parse import quote, urlencode, quote_plus, unquote
import json
from bs4 import BeautifulSoup as bs

import copy
import os
import datetime as dt
import time as t
import numpy as np
import pandas as pd
import random as rd

from tqdm.notebook import tqdm as tq

# %% [markdown]
# ## 한국경제

# %%
url = 'https://www.hankyung.com/it/article/202109144298v'
req = Request(url, headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36'}
)
t.sleep(0.3)
page = urlopen(req)
page = bs(page, 'html.parser')
page
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <title>조승래 의원 발의 데이터기본법 국회 상임위 통과 | 한경닷컴</title>
# <meta content="조승래 의원 발의 '데이터기본법' 국회 상임위 통과, 산업" name="description"/>
# <meta content="IT·과학, " name="news_keywords"/>
# <meta charset="utf-8">
# <meta content="text/html" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=1512, user-scalable=yes" name="viewport"/>
# <meta content="it" name="classification"/>
# <meta content="2021-09-14" property="article:published"/>
# <meta content="872625546175034" property="fb:app_id"/>
# <meta content="https://www.hankyung.com/it/article/202109144298v" property="og:url"/>
# <meta content="article" property="og:type"/>
# <meta content="조승래 의원 발의 '데이터기본법' 국회 상임위 통과" property="og:title"/>
# <meta content="조승래 의원 발의 '데이터기본법' 국회 상임위 통과, 산업" property="og:description"/>
# <meta content="hankyung.com" property="og:site_name"/>
# ...

# %%
page.title.text
# Out:
# '조승래 의원 발의 데이터기본법 국회 상임위 통과 | 한경닷컴'

# %%
# page.find_all('div', 'text')[0].text
# <p class="txt"></p>

# page.find('p', class_="txt")
page.find('div', id='articletxt').text
# Out:
# '\n\n\n\n\n\n\n\n더불어민주당 조승래 의원(대전 유성구갑)이 대표발의한\'데이터기본법\'이14일 국회 과학기술정보방송통신위원회 전체회의에서 의결됐다.법제사법위원회를 거쳐9월 본회의 통과가 유력시된다.지난해12월 조승래 의원이 대표발의한 데이터기본법은 민간 데이터의 생산,거래,활용 등을 촉진하고 관련 산업의 예측 가능성을 높이는 등 데이터 산업 발전의 제도적 기반을 마련하기 위해 추진된 제정법이다.한국판 뉴딜을 입법적으로 뒷받침하기 위해 마련된 민주당 미래전환 뉴딜10대 입법과제 중 첫 번째 과제다.법 통과로 국무총리 소속 국가데이터정책위원회 설치,데이터산업 진흥 기본계획 수립,데이터 산업 실태조사 등 데이터의 유통과 거래,이용 촉진을 위한 정부 정책이 시행될 것으로 기대된다.조승래 의원은"데이터 경제,디지털 전환의 시대에 적극적으로 대응하기 위한 제도적 뒷받침이 필요하다"며"데이터기본법 제정으로 대한민국이 전 세계를 선도하는 디지털 강국으로 거듭날 수 있을 것"이라고 말했다.서동민 한경닷컴 게임톡 기자\n\t\t\t\t\t\t\t\t'

# %% [markdown]
# ## 매일경제

# %%
url = 'https://www.mk.co.kr/news/culture/view/2021/09/884156/'
req = Request(url, headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36'}
)
t.sleep(0.3)
page = urlopen(req)
page = bs(page, 'html.parser')
page
# Out:
# <!DOCTYPE html>
#
# <html class="story" itemid="https://www.mk.co.kr/news/culture/view/2021/09/884156/" itemscope="" itemtype="http://schema.org/NewsArticle" lang="ko" xmlns:og="http://opengraphprotocol.org/schema/">
# <head>
# <title data-rh="true">[오늘의 매일경제TV] 소상공인의 새로운 희망 파트너 - 매일경제</title>
# <link href="https://www.mk.co.kr/news/culture/view/2021/09/884156/" rel="canonical"/>
# <link href="https://m.mk.co.kr/news/culture/view-amp/2021/09/884156/" rel="amphtml"/>
# <link href="https://m.mk.co.kr/news/culture/view/2021/09/884156/" media="only screen and ( max-width: 640px)" rel="alternate"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="ko" data-rh="true" itemprop="inLanguage">
# <meta content="2021-09-14T00:01:02+09:00" data-rh="true" itemprop="datePublished dateCreated" property="article:published"/>
# <meta content="2021-09-14T00:01:02+09:00" data-rh="true" itemprop="dateModified" property="article:modified"/>
# ...

# %%
page.title.text
# Out:
# '[오늘의 매일경제TV] 소상공인의 새로운 희망 파트너 - 매일경제'

# %%
# <div id="article_body" itemprop="articleBody">
# <div class="art_txt">

page.find('div', class_='art_txt').text
# Out:
# '■ 경세제민 촉 (14일 오후 4시)\r이번 주 경세제민 촉에는 조봉환 소상공인시장진흥공단 이사장이 출연한다. 2014년 출범한 소상공인시장진흥공단은 중소벤처기업부 산하 준정부기관으로 전국에 총 70개 지역센터를 운영하며 소상공인을 밀착 지원하고 있다. 올해는 코로나19 장기화로 어려움을 겪는 소상공인들을 위해서 지난달 17일부터 5차 재난지원금인 \'희망회복자금\'을 지급하고 있다. 지원 금액은 방역조치 수준, 방역조치 기간, 규모, 업종 등 피해 정도에 따라 32개 유형으로 세분화해 지원한다. 최근 온라인과 비대면이 강화됨에 따라서 공단은 전통시장에 온라인 서비스를 도입하고, 소상공인의 스마트화를 적극적으로 지원하고 있다. 코로나19 위기 속에서 희망을 찾는 조 이사장을 만나보자.[ⓒ 매일경제 & mk.co.kr, 무단전재 및 재배포 금지]\n        \n\t\t\t\t\t\nwindow.jQuery || document.write("<script src=\'//common.mk.co.kr/common/include/mklib/jquery.js\'>")\n\n'
